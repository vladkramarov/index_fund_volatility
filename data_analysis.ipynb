# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import sys
# sys.path.append('/Users/vladyslavkramarov/Documents/stock_volatility_new')
# sys.path.remove('/Users/vladyslavkramarov/Documents/stock_volatility_new/data_analysis')
print(sys.path)
import loader
import data_analysis.data_analysis_funcs as data_analysis_funcs
# Out:
# ['/Users/vladyslavkramarov/Documents/stock_volatility_new', '/Users/vladyslavkramarov/.vscode/extensions/ms-toolsai.jupyter-2022.11.1003412109/pythonFiles', '/Users/vladyslavkramarov/.vscode/extensions/ms-toolsai.jupyter-2022.11.1003412109/pythonFiles/lib/python', '/Users/vladyslavkramarov/miniforge3/envs/torch-gpu/lib/python310.zip', '/Users/vladyslavkramarov/miniforge3/envs/torch-gpu/lib/python3.10', '/Users/vladyslavkramarov/miniforge3/envs/torch-gpu/lib/python3.10/lib-dynload', '', '/Users/vladyslavkramarov/miniforge3/envs/torch-gpu/lib/python3.10/site-packages', '/Users/vladyslavkramarov/miniforge3/envs/torch-gpu/lib/python3.10/site-packages/mpmath-1.2.1-py3.10.egg']
# ...

# %%
train = loader.get_training_data()

# %%
data_analysis_funcs.qq_plots()

# %%
data_analysis_funcs.plot_autocorrelations(target_feature='log_returns_absolute')

# %%
data_analysis_funcs.violin_plots()

# %%
data_analysis_funcs.compare_train_valid_test_splits('NVDA')

# %%
data_analysis_funcs.compare_train_valid_test_splits('AAPL')

# %%
data_analysis_funcs.compare_train_valid_test_splits('MSFT')
